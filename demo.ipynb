# %% [markdown]
# <h1>DevOps for AI and Machine Learning</h1>
# <h2>Demo #1 - Intro to Jupyter Labs</h2>

# %% [markdown]
# <b>This is a Markdown cell you can use to create structured text</b>

# %% [raw]
# This is a raw text cell you can use for simple text

# %%
# This is a python code cell you can use to create and run software

# create and print a string
str1 = 'hello, world'
print(str1)

# create and print a string by concatenating other strings
str2 = 'hello ' + 'machine ' + 'learning'
print(str2)

# add two numbers and print their result
total = 1 + 1
print('The total is', total)

num1 = 2
num2 = 3
total = num1 + num2
print('The total is', total)
# Out:
# hello, world
# hello machine learning
# The total is 2
# The total is 5

# %%
# This is a python code cell you can use to generate plots of data and results

import matplotlib.pyplot as plt

plt.plot([.9, .5, .2, .1, .05, .05, .045, .045, .045, .045, .045, .045, .045, .045, .045, .045])
plt.plot([.98, .76, .35, .2, .1, 0.07, 0.05, .05, .07, .09, .15, .18, .20, .225, .25, .275])
plt.ylabel('loss')
plt.xlabel('epochs')
plt.show()
